# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures , StandardScaler

# %%
x = np.linspace(0,.5,100)
x.shape
# Out:
# (100,)

# %%
ya = np.cos(2*np.pi*x)**2 # y=cos**2(2πx)
ya.shape
# Out:
# (100,)

# %%
plt.plot(x,ya)
plt.show()

# %%
noice = np.random.normal(0,.1,100) # b/w 0 and 0.1 - 100 noice
print(noice)
# Out:
# [-0.06986765  0.15449075 -0.02958073  0.05529212 -0.0490873  -0.02821843
#  -0.07927945  0.0586426   0.14615917  0.06367778 -0.0469631   0.11788657
#  -0.03279276  0.05993959 -0.11437914 -0.01591982  0.11922015 -0.05288996
#  -0.0596284   0.08681969 -0.04764802 -0.02238935  0.04503597  0.05214441
#   0.02604318 -0.02497179  0.0782252   0.09334063 -0.02930551  0.03288392
#  -0.03567218  0.06297357 -0.04596048 -0.04773627 -0.00685948  0.04318129
#   0.07360216  0.0764691  -0.05385245  0.13231596 -0.00519002  0.08747507
#   0.04371543 -0.21385659 -0.10626772 -0.03113778 -0.07385281 -0.11456471
#  -0.11375892 -0.03574223 -0.02258839  0.14096836  0.02635526 -0.1310627
#  -0.09304144  0.04318661  0.10988603 -0.0583184  -0.00447545 -0.09397984
#  -0.22108777 -0.29473312 -0.11993612 -0.10611993  0.00199797 -0.01639154
#  -0.10075394  0.12283987  0.03848283  0.05868783  0.05299479 -0.03593095
#  -0.08883628  0.08931147 -0.00404367  0.00442832  0.22156259  0.26294623
# ...

# %%
plt.plot(x,ya,color = 'green')
y = ya + noice
#plt.plot(x,y)
plt.scatter(x,y,color = "red")


plt.title("Polynomialdata_add_noice")


# Add a legend
plt.legend()

file_path = r"T:\My Drive\000 ihsan\02 Courses\003GIT\MYProject\Polynomialfeatures\plot\polydataplot.jpg"
plt.savefig(file_path, format='jpg', dpi=300)

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
model = linear_model.LinearRegression()

# %%
x = x.reshape(-1,1) # error bfore reshape [100,1]
model.fit(x,y)
# Out:
# LinearRegression()

# %%
ypredict =model.predict(x)

# %%
plt.plot(x,ya,color = 'green')
y = ya + noice
plt.plot(x,ypredict)
plt.scatter(x,y,color = "red")


plt.title("Polynomialdata_linear_test")


# Add a legend
plt.legend()

file_path = r"T:\My Drive\000 ihsan\02 Courses\003GIT\MYProject\Polynomialfeatures\plot\polylinear.jpg"
plt.savefig(file_path, format='jpg', dpi=300)

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plolynoimialfeatures = PolynomialFeatures(degree = 100,include_bias=True) # include_bias = "True" - theeta 0 * x0 - xo = 1 , this feature true ,
#degree = 100 change 2 to 100 plot change correct , degree increase , correct plot probability increase , not accurate in test ,

# %%
linear = linear_model.LinearRegression(fit_intercept=True)

# %%
pipeline = Pipeline([("polynomial",plolynoimialfeatures),("linear",linear)]) # call pipe line data go through polynomial and linear

# %%
pipeline.fit(x,y)
# Out:
# Pipeline(steps=[('polynomial', PolynomialFeatures(degree=100)),
#                 ('linear', LinearRegression())])

# %%
y_predict = pipeline.predict(x)

# %%
y_predict
# Out:
# array([ 0.97834887,  1.03401521,  1.0316793 ,  1.01035254,  0.98878046,
#         0.97363192,  0.96505205,  0.96026369,  0.955758  ,  0.94849639,
#         0.93644697,  0.91869774,  0.8953239 ,  0.86713485,  0.83538529,
#         0.80150432,  0.76687276,  0.73266201,  0.69973643,  0.66861331,
#         0.63947039,  0.61218867,  0.5864183 ,  0.56165605,  0.53732454,
#         0.51284575,  0.4877031 ,  0.46148892,  0.43393562,  0.40493094,
#         0.37451841,  0.34288541,  0.31034148,  0.27729015,  0.24419701,
#         0.21155698,  0.17986302,  0.14957847,  0.12111386,  0.09480964,
#         0.0709248 ,  0.04963139,  0.03101479,  0.01507861,  0.00175393,
#        -0.00908834, -0.0176229 , -0.02405383, -0.02859778, -0.03146715,
#        -0.03285392, -0.03291466, -0.03175685, -0.02942794, -0.02590647,
#        -0.02109678, -0.0148274 , -0.00685386,  0.00313354,  0.01549628,
#         0.03062847,  0.04893164,  0.0707842 ,  0.096506  ,  0.1263198 ,
# ...

# %%
plt.plot(x,ya,color = 'green')
plt.plot(x,y_predict)
plt.scatter(x,y,color = "red")


plt.title("PolynomialFeatures_degree_100")


# Add a legend
plt.legend()

file_path = r"T:\My Drive\000 ihsan\02 Courses\003GIT\MYProject\Polynomialfeatures\plot\polydegree100.jpg"
plt.savefig(file_path, format='jpg', dpi=300)


plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# add scale
scalar = StandardScaler() # more feature scale must
pipelinescale = Pipeline([("polynomial",plolynoimialfeatures),("Scaling",scalar),("linear",linear)]) # call pipe line data go through polynomial and linear

# %%
pipelinescale.fit(x,y)
# Out:
# Pipeline(steps=[('polynomial', PolynomialFeatures(degree=100)),
#                 ('Scaling', StandardScaler()), ('linear', LinearRegression())])

# %%
y_predict = pipelinescale.predict(x)

# %%
plt.plot(x,ya,color = 'green')
plt.plot(x,y_predict)
plt.scatter(x,y,color = "red")


plt.title("PolynomialFeatures_StandardScaler")


# Add a legend
plt.legend()

file_path = r"T:\My Drive\000 ihsan\02 Courses\003GIT\MYProject\Polynomialfeatures\plot\stdpoly.jpg"
plt.savefig(file_path, format='jpg', dpi=300)

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
